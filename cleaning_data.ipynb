# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/dataset.csv')

# %%
df
# Out:
#                                               content
# 0   @TheAltfather007 @CryptoSl369 Do you want some...
# 1   https://t.co/JHDQZURGyj UK: Cryptocurrency Elr...
# 2   SmartMoneyAlert🚨\n\n@AlamedaResearch just tran...
# 3   Saw this degen in my part of the country. Texa...
# 4   Cryptocurrency Titan Coinbase Providing “Geo T...
# ..                                                ...
# 95  Bitcoin price: June close barely beats 2017 hi...
# 96  MakerDAO members shoot down proposal for more ...
# 97  Multisigs mean funds in bridges are ‘one small...
# 98  Hundreds of Bored Ape owners sign up to hire o...
# 99  Better days ahead with crypto deleveraging com...
#
# [100 rows x 1 columns]

# %%
#cleaning text
import re
import string

def clean_text(tweet):
  tweet = tweet.lower() #membuat text nya menjadi huruf kecil semua
  tweet = re.sub('@[^\s]+', '', tweet) #remove usernames
  tweet = re.sub('\[.*?\]', '', tweet) #remove square brackets
  tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', tweet) #remove link/url
  tweet = re.sub('[%s]' % re.escape(string.punctuation), '', tweet) #remove karakter/tanda baca yang tidak diperlukan
  tweet = re.sub('\w*\d\w*', '', tweet) #remove karakter yang tidak diperlukan
  tweet = re.sub('[‘’“”…]', '', tweet) #remove karakter yang tidak diperlukan
  tweet = re.sub('\n', '', tweet) #remove karakter yang tidak diperlukan
  return tweet

tweet = lambda x: clean_text(x)

# %%
df['clean1'] = pd.DataFrame(df.content.apply(tweet))

# %%
df
# Out:
#                                               content  \
# 0   @TheAltfather007 @CryptoSl369 Do you want some...
# 1   https://t.co/JHDQZURGyj UK: Cryptocurrency Elr...
# 2   SmartMoneyAlert🚨\n\n@AlamedaResearch just tran...
# 3   Saw this degen in my part of the country. Texa...
# 4   Cryptocurrency Titan Coinbase Providing “Geo T...
# ..                                                ...
# 95  Bitcoin price: June close barely beats 2017 hi...
# 96  MakerDAO members shoot down proposal for more ...
# 97  Multisigs mean funds in bridges are ‘one small...
# 98  Hundreds of Bored Ape owners sign up to hire o...
# 99  Better days ahead with crypto deleveraging com...
#
#                                                clean1
# 0     do you want someone to tell you sorry lolzz ...
# 1    uk cryptocurrency elrond up more than  in  ho...
# 2   smartmoneyalert🚨 just transferred  usdp to bin...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats  high as...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
# [100 rows x 2 columns]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
additional = ['rt', 'rts', 'retweet']
swords = set().union(stopwords.words('indonesian'), additional)

df['clean2'] = (df['clean1'].apply(lambda x: ' '.join([word for word in x.split() if word not in (swords)])))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fandl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df
# Out:
#                                               content  \
# 0   @TheAltfather007 @CryptoSl369 Do you want some...
# 1   https://t.co/JHDQZURGyj UK: Cryptocurrency Elr...
# 2   SmartMoneyAlert🚨\n\n@AlamedaResearch just tran...
# 3   Saw this degen in my part of the country. Texa...
# 4   Cryptocurrency Titan Coinbase Providing “Geo T...
# ..                                                ...
# 95  Bitcoin price: June close barely beats 2017 hi...
# 96  MakerDAO members shoot down proposal for more ...
# 97  Multisigs mean funds in bridges are ‘one small...
# 98  Hundreds of Bored Ape owners sign up to hire o...
# 99  Better days ahead with crypto deleveraging com...
#
#                                                clean1  \
# 0     do you want someone to tell you sorry lolzz ...
# 1    uk cryptocurrency elrond up more than  in  ho...
# 2   smartmoneyalert🚨 just transferred  usdp to bin...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats  high as...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
#                                                clean2
# 0   do you want someone to tell you sorry lolzz yo...
# 1   uk cryptocurrency elrond up more than in hours...
# 2   smartmoneyalert🚨 just transferred usdp to bina...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats high as ...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
# [100 rows x 3 columns]

# %%
text = df['clean2']

# %%
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

# factory = StemmerFactory()
# stemmer = factory.create_stemmer()
# stemmer = PorterStemmer()
stemmer = LancasterStemmer()

list_hasil = text

output = [(stemmer.stem(token)) for token in list_hasil]

# %%
output
# Out:
# ['do you want someone to tell you sorry lolzz you have lost your mind you are responsible for your actions when its has to do with cryptocurrency man up and cry in silence why are you sounding like the father of karma do you even know what karma mean',
#  'uk cryptocurrency elrond up more than in hours by benzingaelrondnetwork egld',
#  'smartmoneyalert🚨 just transferred usdp to binancesmartmoney bitcoin ethereum cryptocurrency whalealert stablecoin',
#  'saw this degen in my part of the country texas folks on the move wrapped in doge might be a sign degen dogecoin crypto cryptocurrency wrapped',
#  'cryptocurrency titan coinbase providing geo tracking data to ice',
#  'terra virtua tvk went up percent in the last minutes on binance tvk crypto bitcoin cryptocurrency btc ethereum blockchain eth trading altcoin binance cryptonews',
#  'has crypto made anything better rcryptocurrency',
#  'a couple of months ago i tried to warn this sub about the risks of lending your coins and was laughed out of the room rcryptocurrency',
#  'nft sales hit low after cryptocurrency crash cryptocurrency via',
#  'deal affiliate affiliatemarketing bitcoin blogger business cryptocurrency deals discount gifts marketing shopping socialmedia travel twitter webtalk ad gifts baskets chocolate fruits wine gourmet',
#  'doge one of the most mentioned on over the last hours via doge cryptocurrency',
#  'luisesman found in a user vault at this location join me playing coinhuntworld its awesome cryptocurrency',
#  'university of cincinnati in 🇺🇸us launching cryptoeconomics lab amp 🪙crypto fundcryptonews cryptocurrency cincinnati',
#  'the cryptocurrency market worth about last november is now worth less than',
#  'so how is russia paying mtgthrough a gobetween like arron banks or with cryptocurrency',
#  'a new report issued by mastercard the payment processing giant has found that most consumers in latam have knowledge of what cryptocurrency is the report states that more than half of the consumersin latam have at least made a transaction involving',
#  'towerbee tbe went up percent in the last minutes on tbe crypto bitcoin cryptocurrency btc ethereum blockchain eth trading altcoin binance cryptonews',
#  'top best bitcoin projects to learn about in cryptocurrencymarket cryptocurrencies bitcoinprojects crypto bitcoin btc btcprojects cryptocurrency ai ainews analyticsinsight analyticsinsightmagazine',
#  'as cryptocurrency becomes more widespread well have a world where money is easy to access easy to move easy to send easy to receive and easy to investcrypto bnb eth binance',
#  'motion and inertia in odia does heavy object fall earlier than lighter object ico cryptocurrency nearprotocol near airdrop decentralizationofeducation equal oppurtunity no discrimination between english medium and odia medium',
#  'nonfungibletokensnftscryptocurrenciestechnologybusiness nft sales hit low after cryptocurrency crash the guardian signup hipeople',
#  'when the shibanft app is released very soon prepare for a tsunami of newbies into the space this app is a game changer💥🚀 nft crypto cryptocurrency nfts xrpl xrp xsquad xrdc xspectar doge shib lunc loveisland',
#  'algorands token is bullish but where are the buyers crypto cryptocurrency cryptonews ico btc blockchain eth bitcoin airdrop one',
#  'i put in stepn move to earn last month now its down id need to run every day for a year just to break even cryptocurrency from reddit',
#  'i put in stepn move to earn last month now its down id need to run every day for a year just to break even cryptocurrency',
#  'snoop dogg spoke about the crypto crash in an interview with cnbc on tuesday and explained that he believes the cryptocurrency economy will bounce back snoop said that he feels like the crash weeded out all of the people that were not supposed to be in the space in the first',
#  'for sale cryptocurrency metaverse',
#  'nft sales hit low after cryptocurrency crashsales of nonfungible tokens totalled just over in june compared with peak of in january',
#  'bitcoin xrp crypto cryptocurrency ethereum nft shib metaverse',
#  'maybe want to check nfts and you might love how unique every planet 🪐apeiron has am i right 🤩nft cryptocurrency ap',
#  'cryptocurrency market top cryptocurrency news on june bitcoin at rs lakh tds on cryptos from july nfts and more',
#  'cryptocurrency market street artist alec monopoly and hypermint collaborate to release nfts',
#  'cryptocurrency market what shiba inu price needs to do to trigger a breakout',
#  'cryptocurrency निवेश पर है कोई confusion crypto का संकट अभी और गहराएगा consumer adda',
#  '🚨🚨🚨 crypto alert• macd cross alert • pair crypto nft defi cryptocurrency trading',
#  'want the best signal in cryptocurrency waves feiusd',
#  'real project that will revolutionize the cryptocurrency industry',
#  'real project that will revolutionize the cryptocurrency industry 👋👋',
#  'when starting out in cryptocurrency investment the first mistake we all must have to make is not arranging our portfolio and categorizing them in order to avoid this mistake you need to be educated first',
#  'deal affiliate affiliatemarketing bitcoin blogger business cryptocurrency deals discount gifts marketing shopping socialmedia travel twitter webtalk ad freeshipping steak steaknight chicken seafood wine',
#  'real project that will revolutionize the cryptocurrency industry✅✅',
#  'i took out a loan to buy btc bitcoin btc cryptocurrency crypto blockchain',
#  'prices for secondhand luxury watches fall as cryptocurrency wealth disappear',
#  'ipollo mini asic crypto miner with collectable picture bitcoin crypto cryptocurrency nfts ethereum',
#  'bscnews do you know what happens after a coinbase listing come see how the effect worksbscnews cryptocurrency defi',
#  'prices for secondhand luxury watches fall as cryptocurrency wealth disappears the national',
#  '🎉join kucoin via this link and get off your trading fees plus up to usdt joining bonus➡️ utccryptotrading bitcoin cryptocurrency cryptomarket etherum cryptonews cryptos',
#  '🎉join binance via this link and get off your trading fees plus up to usdt joining bonus➡️ utccryptotrading bitcoin cryptocurrency cryptomarket etherum cryptonews cryptos',
#  'the woman alleged to be at the heart of one of the worlds biggest cryptocurrency frauds is now on the fbis most wanted fugitives list according to the agency',
#  'it is a sort of amway meets cryptocurrency fraudand lots of people worldwide were scammed of their savings one scottish lady tells of her guilt that she introduced others to it total loss € when she was still in the fervent belief stage',
#  'fantastic airdrop project the tokapp is going to change entire scenario in crypto currency world',
#  'makerdao members shoot down proposal for more centralization cryptocurrency',
#  'hundreds of bored ape owners sign up to hire out their nfts to brands cryptocurrency',
#  'fantastic airdrop project the tokapp is going to change entire scenario in crypto currency worldshibadoge',
#  'luna classic and ustc correction – top altcoin cryptocurrency prices today',
#  'onecoin founder ruja ignatova listed on fbi top most wanted fugitives listknow more voc voiceofcrypto crypto cryptocurrency cryptoupdate fbi onecoin',
#  'luna classic and ustc correction – top altcoin cryptocurrency prices today',
#  'nft sales hit low after cryptocurrency crash nonfungible tokens nfts the guardian',
#  'nft sales hit low after cryptocurrency crash nonfungible tokens nfts the guardian',
#  'university of cincinnati launching cryptoeconomics lab and cryptocurrency fund',
#  '📢 robostopia smart cryptocurrency trader bot for binance and bittrex✅ trailing stoploss buy or sell altcoins btc pairs✅ auto renew orders✅ profit loss notifications by transactions✅ completed order notifications and many more👉',
#  'how will society regulate cryptocurrency via regtechcc',
#  'deal affiliate affiliatemarketing bitcoin blogger business cryptocurrency deals discount gifts marketing shopping socialmedia travel twitter webtalk ad drinks alcohol beer wine liquor',
#  'introducing triggerme telegram bot for tracking the markets realtimeequitycryptocurrencyindicescryptobe with the price track it liveaccess bot on telegram details',
#  'everrise rise everrevoke defi crypto cryptocurrency nftproject buildstuff nft avax everown utilitynft nfts ris',
#  'everrise rise everrevoke everriseedu defi crypto cryptocurrency everown nftstakes polygon bnb altcoin everriseinu',
#  'loser token phx price down volume cryptocurrency',
#  'blockfi announces deal with ftx us including option to acquire for via cointelegraph cryptocurrencynews cryptocurrency crypto cryptonews',
#  'ethereum merge delay could put its chances of overtaking bitcoin as the top cryptocurrency at risk the number two',
#  'top up cryptocurrency in last minute nbt usdt tvk usdt mbl usdt usdt btcst usdt to the moon',
#  'top down cryptocurrency in last minute burger usdt stmx usdt bttc usdt troy usdt nexo usdt down to earth',
#  'high volatile cryptocurrency in last minute mbl usdt burger usdt tvk usdt usdt nbt usdt moon or ear',
#  'crypto ape news bitcoin bears have plenty of reasons to hold btc price below since might the bitcoin btc cryptocurrency crypto cryptonews',
#  'microsoft has a twitter thread on the recent activities of the gang a cryptocurrencymining group active since early cryptocurency cryptocurrencies blockchain microsoft',
#  'voyager digital freezes trading deposits withdrawals and rewards blames default cryptocurrency',
#  'bitcoin trader says expect more chop downside then sideways price action for btc this summer cryptocurrency',
#  'battlehardened ronin bridge reopens following hack finance redefined cryptocurrency',
#  'blockfi announces deal with ftx us including option to acquire for cryptocurrency',
#  'price analysis btc eth bnb xrp sol doge dot leo shib cryptocurrency',
#  'ignite ceo announces departure after seven years cryptocurrency',
#  'june roundup whos hiring and whos firing in the crypto space cryptocurrency',
#  'june gloom takes on a new meaning in another down month cryptocurrency',
#  'bear market so what says world chess champion garry kasparov cryptocurrency',
#  'tether continues to reduce commercial paper in sharp reduction since march cryptocurrency',
#  'argentina carries out crypto wallet seizures linked to tax delinquents cryptocurrency',
#  'ashanti aims to bring women to says owning is important at nft music meetup cryptocurrency',
#  'experts weigh in on european unions mica crypto regulation cryptocurrency',
#  'ton foundation launches ethereum name servicelike domain names cryptocurrency',
#  'from currency to religion hmmmmm que an emoji where the character is internalizing what exactly cryptocurrency is 💆🏾\u200d♂️',
#  'what bear market this token is quietly making new highs up against bitcoin in cryptocurrency',
#  'blockchains how crypto winter could slow the challenge to ethereum cryptocurrency',
#  'selfcustody is key during extreme market conditions heres what experts say cryptocurrent',
#  'deutsche bank analysts see bitcoin recovering to by december cryptocurrency',
#  'coinbase denies reports of selling customer data to the us government cryptocurrency',
#  'not giving up vaneck refiles with sec for spot bitcoin etf cryptocurrency',
#  'bitcoin price june close barely beats high as coinbase premium flips positive cryptocurrency',
#  'makerdao members shoot down proposal for more centralization cryptocurrency',
#  'multisigs mean funds in bridges are one small slipup from being hacked cryptocurrency',
#  'hundreds of bored ape owners sign up to hire out their nfts to brands cryptocurrency',
#  'better days ahead with crypto deleveraging coming to an end — jpmorgan cryptocurrency']

# %%
df['clean3'] = output

# %%
df
# Out:
#                                               content  \
# 0   @TheAltfather007 @CryptoSl369 Do you want some...
# 1   https://t.co/JHDQZURGyj UK: Cryptocurrency Elr...
# 2   SmartMoneyAlert🚨\n\n@AlamedaResearch just tran...
# 3   Saw this degen in my part of the country. Texa...
# 4   Cryptocurrency Titan Coinbase Providing “Geo T...
# ..                                                ...
# 95  Bitcoin price: June close barely beats 2017 hi...
# 96  MakerDAO members shoot down proposal for more ...
# 97  Multisigs mean funds in bridges are ‘one small...
# 98  Hundreds of Bored Ape owners sign up to hire o...
# 99  Better days ahead with crypto deleveraging com...
#
#                                                clean1  \
# 0     do you want someone to tell you sorry lolzz ...
# 1    uk cryptocurrency elrond up more than  in  ho...
# 2   smartmoneyalert🚨 just transferred  usdp to bin...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats  high as...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
#                                                clean2  \
# 0   do you want someone to tell you sorry lolzz yo...
# 1   uk cryptocurrency elrond up more than in hours...
# 2   smartmoneyalert🚨 just transferred usdp to bina...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats high as ...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
#                                                clean3
# 0   do you want someone to tell you sorry lolzz yo...
# 1   uk cryptocurrency elrond up more than in hours...
# 2   smartmoneyalert🚨 just transferred usdp to bina...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats high as ...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
# [100 rows x 4 columns]

# %%
df.dropna()
# Out:
#                                               content  \
# 0   @TheAltfather007 @CryptoSl369 Do you want some...
# 1   https://t.co/JHDQZURGyj UK: Cryptocurrency Elr...
# 2   SmartMoneyAlert🚨\n\n@AlamedaResearch just tran...
# 3   Saw this degen in my part of the country. Texa...
# 4   Cryptocurrency Titan Coinbase Providing “Geo T...
# ..                                                ...
# 95  Bitcoin price: June close barely beats 2017 hi...
# 96  MakerDAO members shoot down proposal for more ...
# 97  Multisigs mean funds in bridges are ‘one small...
# 98  Hundreds of Bored Ape owners sign up to hire o...
# 99  Better days ahead with crypto deleveraging com...
#
#                                                clean1  \
# 0     do you want someone to tell you sorry lolzz ...
# 1    uk cryptocurrency elrond up more than  in  ho...
# 2   smartmoneyalert🚨 just transferred  usdp to bin...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats  high as...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
#                                                clean2  \
# 0   do you want someone to tell you sorry lolzz yo...
# 1   uk cryptocurrency elrond up more than in hours...
# 2   smartmoneyalert🚨 just transferred usdp to bina...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats high as ...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
#                                                clean3
# 0   do you want someone to tell you sorry lolzz yo...
# 1   uk cryptocurrency elrond up more than in hours...
# 2   smartmoneyalert🚨 just transferred usdp to bina...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats high as ...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
# [100 rows x 4 columns]

# %%
nltk.download('punkt')
df['tokens'] = pd.DataFrame(df['clean3'].apply(nltk.word_tokenize))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fandl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df
# Out:
#                                               content  \
# 0   @TheAltfather007 @CryptoSl369 Do you want some...
# 1   https://t.co/JHDQZURGyj UK: Cryptocurrency Elr...
# 2   SmartMoneyAlert🚨\n\n@AlamedaResearch just tran...
# 3   Saw this degen in my part of the country. Texa...
# 4   Cryptocurrency Titan Coinbase Providing “Geo T...
# ..                                                ...
# 95  Bitcoin price: June close barely beats 2017 hi...
# 96  MakerDAO members shoot down proposal for more ...
# 97  Multisigs mean funds in bridges are ‘one small...
# 98  Hundreds of Bored Ape owners sign up to hire o...
# 99  Better days ahead with crypto deleveraging com...
#
#                                                clean1  \
# 0     do you want someone to tell you sorry lolzz ...
# 1    uk cryptocurrency elrond up more than  in  ho...
# 2   smartmoneyalert🚨 just transferred  usdp to bin...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats  high as...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
#                                                clean2  \
# 0   do you want someone to tell you sorry lolzz yo...
# 1   uk cryptocurrency elrond up more than in hours...
# 2   smartmoneyalert🚨 just transferred usdp to bina...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats high as ...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
#                                                clean3  \
# 0   do you want someone to tell you sorry lolzz yo...
# 1   uk cryptocurrency elrond up more than in hours...
# 2   smartmoneyalert🚨 just transferred usdp to bina...
# 3   saw this degen in my part of the country texas...
# 4   cryptocurrency titan coinbase providing geo tr...
# ..                                                ...
# 95  bitcoin price june close barely beats high as ...
# 96  makerdao members shoot down proposal for more ...
# 97  multisigs mean funds in bridges are one small ...
# 98  hundreds of bored ape owners sign up to hire o...
# 99  better days ahead with crypto deleveraging com...
#
#                                                tokens
# 0   [do, you, want, someone, to, tell, you, sorry,...
# 1   [uk, cryptocurrency, elrond, up, more, than, i...
# 2   [smartmoneyalert🚨, just, transferred, usdp, to...
# 3   [saw, this, degen, in, my, part, of, the, coun...
# 4   [cryptocurrency, titan, coinbase, providing, g...
# ..                                                ...
# 95  [bitcoin, price, june, close, barely, beats, h...
# 96  [makerdao, members, shoot, down, proposal, for...
# 97  [multisigs, mean, funds, in, bridges, are, one...
# 98  [hundreds, of, bored, ape, owners, sign, up, t...
# 99  [better, days, ahead, with, crypto, deleveragi...
#
# [100 rows x 5 columns]

# %%
df.to_csv('dataset/dataset_clean.csv')
